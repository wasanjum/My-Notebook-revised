# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ### Waseem Anjum
#
# Financial Institute (Banks, Insurance)

# %% [markdown]
# *I am interested in data science because I have scene how the datat sciene has changed the approaches the business decision and risk in the business can be expected minimum, Artificial intellegence has changed the technology from remote control to self decision and acting independly which is very much interested for me and the banks also very much keen to adapt the data science to have control over the product and product features.*

# %% [markdown]
# ### Next cell will be simple math

# %%
10+5-3
# Out:
# 12

# %% [markdown]
# ### Hurizontal Rule
#
# - - -
# This trying hurizontal
# - - -
# Hyphens
# - - -
# Asterisk
# - - -
#
# ### Number List
#
# 1. one item
# 2. second item
# 3. third item
#
#
# ### Bullet List
#
# *
# *
# *
#
# ### Hyper Link
#
# [Visit Twitter](https://twitter.com)
#
# [Visit my Notebook](https://https://dataplatform.cloud.ibm.com/analytics/notebooks/v2/c4d759f7-1dd2-4cbd-a3f0-906cf9b779c0/view?access_token=4381c1a463f285c5df19f41205fb03d74fb48e537c547dfe9f3285f860f7d035)
#
#
# ### HTML
#
# This*is*trying*html*
#
# ### Blockquotes
#
# > this is trying **blockquotes**
#
# ### Image
#
# ![Image.jpg](attachment:Image.jpg)
#
# ### Code and Syntax Highlighting
#
# This is `trying` code and `syntax` `highlighting`
#
# ### Strikethrough
#
# ~~this is trying strikethrough~~
#
# ### Table
#
#
# |   First       |  Second     |  Third      |
# |---------------|-------------|-------------|
# |   001         |    002      |    003      |
# |    A          |     B       |     C       |
# |  Test 1       | test 2      |  Test 3     |
# |    X          |    Y        |    Z        |
